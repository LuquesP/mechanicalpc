# %%
# !git clone https://github.com/LuquesP/mechanicalpc.git
# Out:
# Cloning into 'mechanicalpc'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 152 (delta 80), reused 109 (delta 40), pack-reused 0
# Receiving objects: 100% (152/152), 37.64 MiB | 27.12 MiB/s, done.
# Resolving deltas: 100% (80/80), done.

# %%
# !git pull
# Out:
# CONFLICT (add/add): Merge conflict in src/networks/repsurf/util/utils.py
# Auto-merging src/networks/repsurf/util/utils.py
# CONFLICT (add/add): Merge conflict in src/networks/repsurf/modules/pointops/setup.py
# Auto-merging src/networks/repsurf/modules/pointops/setup.py
# CONFLICT (add/add): Merge conflict in src/networks/repsurf/modules/pointnet2_utils.py
# Auto-merging src/networks/repsurf/modules/pointnet2_utils.py
# Automatic merge failed; fix conflicts and then commit the result.

# %%
# !git config --global user.email "lukas.jo.pilsl@gmail.com"

# %%
# !git config --global user.name "LuquesP"

# %%
# %cd /home/jovyan/mechanicalpc/src
# Out:
# /home/jovyan/mechanicalpc/src

# %%
# %cd networks/repsurf/modules/pointops
# Out:
# [Errno 2] No such file or directory: 'networks/repsurf/modules/pointops'
# /home/jovyan/mechanicalpc/src/networks/repsurf/modules/pointops

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing pointops.egg-info/PKG-INFO
# writing dependency_links to pointops.egg-info/dependency_links.txt
# writing top-level names to pointops.egg-info/top_level.txt
# /opt/conda/lib/python3.8/site-packages/torch/utils/cpp_extension.py:369: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# reading manifest file 'pointops.egg-info/SOURCES.txt'
# writing manifest file 'pointops.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# building 'pointops_cuda' extension
# ...

# %%
# !nvidia-smi
# Out:
# Thu Nov  3 00:04:54 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.141.03   Driver Version: 470.141.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  On   | 00000000:3B:00.0 Off |                    2 |
# | N/A   29C    P0    25W / 250W |      2MiB / 12198MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# !nvidia-smi --version
# Out:
# Invalid combination of input arguments. Please run 'nvidia-smi -h' for help.

# %%
# !nvidia-smi dmon -i 0 -s mu -d 5 -o TD
# Out:
# #Date       Time        gpu    fb  bar1    sm   mem   enc   dec
# #YYYYMMDD   HH:MM:SS    Idx    MB    MB     %     %     %     %
#  20221013   18:58:36      0     0     2     0     0     0     0
#  20221013   18:58:41      0     0     2     0     0     0     0
# ^C

# %%
t = torch.cuda.get_device_properties(0).total_memory
r = torch.cuda.memory_reserved(0)
a = torch.cuda.memory_allocated(0)
f = r-a
print(t)
# Out:
# 12790923264

# %%
# !pip install wandb
# Out:
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /opt/conda/include/python3.8/UNKNOWN
# sysconfig: /opt/conda/include/python3.8
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# ...
#   Using cached wandb-0.13.4-py2.py3-none-any.whl (1.9 MB)
# ...
#   Using cached sentry_sdk-1.9.10-py2.py3-none-any.whl (162 kB)
# ...
#   Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# ...
#   Using cached setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# ...
#   Using cached shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# ...
#   Using cached GitPython-3.1.29-py3-none-any.whl (182 kB)
# ...
#   Using cached promise-2.3-py3-none-any.whl
# ...
#   Using cached pathtools-0.1.2-py3-none-any.whl
# ...
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# ...
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# ...

# %%
# !pip install gdown
# Out:
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /opt/conda/include/python3.8/UNKNOWN
# sysconfig: /opt/conda/include/python3.8
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Using cached filelock-3.8.0-py3-none-any.whl (10 kB)
# ...
#   Created wheel for gdown: filename=gdown-4.5.3-py3-none-any.whl size=14820 sha256=0398daad9060919eaeabbd715c71e24493a6fd5b37094a4a682608aadb83c92b
#   Stored in directory: /home/jovyan/.cache/pip/wheels/2e/bf/38/838f7a301971b6fa2915069198ae7b48a21833d156ef170960
# Successfully built gdown
# ...
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /opt/conda/include/python3.8/UNKNOWN
# sysconfig: /opt/conda/include/python3.8
# ...

# %%
import os
import torch
from utils.utils import get_classes
from utils.utils import cal_loss
from networks.pointnet.pointnet import PointNetCls, feature_transform_regularizer
from networks.pointnet2.pointnet2_cls_ssg import get_model, get_loss
from networks.pct.init_model import pct_get_model
from networks.pointmlp.pointmlp import pointMLP, pointMLPElite
from torch.utils.data import DataLoader
import torch.nn.functional as F
from torch.optim.lr_scheduler import CosineAnnealingLR
from dataloader import get_dataset
import gdown 
import wandb

# %%
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:1

# %%
url = "https://drive.google.com/file/d/1NLY6OUqRyn1OCPAxDSWHAsMnBSf59j_f/view?usp=sharing"
gdown.download(url, "mechanicaldata.zip", fuzzy=True )
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1NLY6OUqRyn1OCPAxDSWHAsMnBSf59j_f
# To: /home/jovyan/mechanicalpc/src/mechanicaldata.zip
# 100%|██████████| 2.55G/2.55G [00:21<00:00, 119MB/s]
# 'mechanicaldata.zip'

# %%
# !unzip -q mechanicaldata.zip

# %%
dataset_path = os.path.join(os.getcwd(), "data")
model_outpath = os.getcwd()
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:1

# %%
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: luaks. Use `wandb login --relogin` to force relogin
# True

# %%
torch.cuda.empty_cache()

# %%
train_annot, train_ds = get_dataset(dataset_path, "train", False)
val_annot, val_ds = get_dataset(dataset_path, "test", False)
train_loader = DataLoader(train_ds, batch_size=64, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=64)

# %%
classes = get_classes(train_annot)
# model = PointNetCls(k=len(classes), feature_transform=False)
model = get_model(len(classes), normal_channel=False)
# model = pct_get_model() 
# model.to(device)
# model = pointMLPElite() 
# model_path = "pointnet_cls_model_33.pth"
# model.load_state_dict(torch.load(model_path, map_location=device))
model.to(device) 
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# optimizer = torch.optim.SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=0.0002)
scheduler = CosineAnnealingLR(optimizer, 20, eta_min=0.005, last_epoch=-1)
feature_transform = False
epochs = 80
save = True
model_name = "pointnet2"
# criterion = cal_loss 
criterion = F.nll_loss

# %%
wandb.init(
        project="mechanicalpc",
        config={
            "epochs": 80,
            "batch_size": 64,
            "lr": 1e-3
            })
config = wandb.config
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: luaks. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/home/jovyan/mechanicalpc/src/wandb/run-20221017_190729-1rbh4g82</code>
# Syncing run <strong><a href="https://wandb.ai/luaks/mechanicalpc/runs/1rbh4g82" target="_blank">splendid-frog-29</a></strong> to <a href="https://wandb.ai/luaks/mechanicalpc" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
for epoch in range(epochs):
    total_train_loss = 0
    correct_examples = 0
    if epoch > 0: 
        scheduler.step() 
    for i, data in enumerate(train_loader, 0):
        points, target = data["pointcloud"], data["category"]
        points = points.transpose(1, 2)
        points, target = points.to(device), target.to(device)
        optimizer.zero_grad()
        model = model.train()
        if model_name == "pct":
            pred = model(points)
        elif model_name == "pointnet":
            pred, trans, _ = model(points)
        else:
            pred, trans = model(points)
        loss = criterion(pred, target)
        loss.backward()
        optimizer.step()
        pred_choice = pred.max(1)[1]
        total_train_loss += loss.item()
        correct_examples += pred_choice.eq(target.data).sum().item()
        if i % 10 == 9:
            print(
                f"[Epoch {epoch + 1}, Batch: {i + 1 } / {len(train_loader)}], Train loss: {((total_train_loss / len(train_loader))*100.0):.4f}, train accuracy: {(correct_examples) / len(train_ds):.4f}"
            )
            metrics = {"train/train_loss":  total_train_loss, 
                       "train/epoch": epoch}
            wandb.log({**metrics})
            total_train_loss = 0
        
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data in val_loader:
            points, target = data["pointcloud"], data["category"]
            points = points.transpose(1, 2)
            points, target = points.to(device), target.to(device)
            # outputs, _, _ = model(points)
            outputs, _ = model(points)
#             outputs = model(points) 
            _, pred = torch.max(outputs.data, 1)
            total += target.size(0)
            correct += (pred == target).sum().item()
        val_acc = 100.0 * correct / total
        print(f"Valid accuracy: {val_acc}")
    if save:
        torch.save(model.state_dict(), "%s/pointnet2_cls_model_%d.pth" % (model_outpath, epoch))
wandb.finish()
# Out:
# [Epoch 1, Batch: 10 / 735], Train loss: 5.1557, train accuracy: 0.0018
# [Epoch 1, Batch: 20 / 735], Train loss: 4.2583, train accuracy: 0.0054
# [Epoch 1, Batch: 30 / 735], Train loss: 3.5742, train accuracy: 0.0104
# [Epoch 1, Batch: 40 / 735], Train loss: 3.3038, train accuracy: 0.0157
# [Epoch 1, Batch: 50 / 735], Train loss: 3.0658, train accuracy: 0.0216
# [Epoch 1, Batch: 60 / 735], Train loss: 2.8095, train accuracy: 0.0283
# [Epoch 1, Batch: 70 / 735], Train loss: 2.7284, train accuracy: 0.0350
# [Epoch 1, Batch: 80 / 735], Train loss: 2.5122, train accuracy: 0.0419
# [Epoch 1, Batch: 90 / 735], Train loss: 2.4456, train accuracy: 0.0492
# [Epoch 1, Batch: 100 / 735], Train loss: 2.1557, train accuracy: 0.0571
# [Epoch 1, Batch: 110 / 735], Train loss: 2.1668, train accuracy: 0.0652
# [Epoch 1, Batch: 120 / 735], Train loss: 2.1656, train accuracy: 0.0732
# [Epoch 1, Batch: 130 / 735], Train loss: 2.0523, train accuracy: 0.0815
# ...

# %%
pointMLP neues training bei 33 gestartet
